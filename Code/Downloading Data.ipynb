# %% [markdown]
# # Downloading Data

# %%
#install rpy2
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr

# %%
base = importr('base')
utils = importr('utils')
stats = importr('stats')

# %%
#install Neon Utilities package - I think I only need to do this once 
#utils.install_packages('neonUtilities', repos='https://cran.rstudio.com/');
neonUtilities = importr('neonUtilities')

# %%
#define sites
sites = ("KONZ", "ORNL", "NIWO", "WREF", "BONA")

# %%
neonUtilities.byFileAOP(dpID='DP3.30015.001', site="WREF", 
                        year='2019', check_size='FALSE',
                       savepath='NEON_CO2_Macrosystems_LIDAR/Code/Data');
# Out:
# ...
#   |======================================================================| 100%
# Successfully downloaded  1485  files.
# NEON_D16_WREF_DP1_589000_5075000_classified_point_cloud.shx downloaded to NEON_CO2_Macrosystems_LIDAR/Code/Data/DP3.30015.001/2019/FullSite/D16/2019_WREF_3/Metadata/DiscreteLidar/TileBoundary/shps
# NEON_D16_WREF_DP1_580000_5071000_classified_point_cloud.shp downloaded to NEON_CO2_Macrosystems_LIDAR/Code/Data/DP3.30015.001/2019/FullSite/D16/2019_WREF_3/Metadata/DiscreteLidar/TileBoundary/shps
# NEON_D16_WREF_DP1_587000_5074000_classified_point_cloud.dbf downloaded to NEON_CO2_Macrosystems_LIDAR/Code/Data/DP3.30015.001/2019/FullSite/D16/2019_WREF_3/Metadata/DiscreteLidar/TileBoundary/shps
# NEON_D16_WREF_DP3_592000_5071000_CHM.tif downloaded to NEON_CO2_Macrosystems_LIDAR/Code/Data/DP3.30015.001/2019/FullSite/D16/2019_WREF_3/L3/DiscreteLidar/CanopyHeightModelGtif
# ...
